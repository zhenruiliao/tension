# %% [markdown]
# # Modify Below
#
# ### Note: Running times are not reproducible

# %%
neuron_list = [20, 40, 60, 80, 100] # number of recurrent neurons
n_epoch = 5
ntrial = 5

# %% [markdown]
# # Import Packages

# %%
try:
  import tension
except ImportError:
  # !git clone https://github.com/zhenruiliao/tension.git tension
  # !pip install -e tension
  print('Stopping RUNTIME! Please run again.')
  import os
  os.kill(os.getpid(), 9)

# %%
import jax.numpy as jnp
from jax import grad, jit, vmap
from jax import random
import numpy as np
import tensorflow as tf
import time

# %%
from tension.base import FORCEModel
from tension.models import NoFeedbackESN
from tension.callbacks import TimeHistory

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(context = 'talk', style = 'ticks')

# %%
SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 12
EXTRA_SIZE = 24
 
plt.rc('font', size=BIGGER_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=EXTRA_SIZE)  # fontsize of the figure title

# %% [markdown]
# # Numpy Implementation of FORCE

# %%
def keygen(key, nkeys):
  """Generate randomness that JAX can use by splitting the JAX keys.
  Args:
    key : the random.PRNGKey for JAX
    nkeys : how many keys in key generator
  Returns:
    2-tuple (new key for further generators, key generator)
  """
  keys = random.split(key, nkeys+1)
  return keys[0], (k for k in keys[1:])

# %%
def random_esn_params(key, u, n, m, tau=1.0, dt=0.1, g=1.0):
  """Generate random RNN parameters
  
  Arguments: 
    u: dim of the input
    n: number of neurons
    m: dim of the output
    tau: "neuronal" time constant
    dt: time between Euler integration updates
    g: scaling of the recurrent matrix in the reservoir

  Returns:
    A dictionary of parameters for the ESN.
  """
  key, skeys = keygen(key, 5)
  hscale = 0.25
  ifactor = 1.0 / jnp.sqrt(u)
  hfactor = g / jnp.sqrt(n)
  pfactor = 1.0 / jnp.sqrt(n)
  ffactor = 1.0 # Feedback factor, keep at 1 for now.
  return {'a0' : random.normal(next(skeys), (n,)) * hscale,
          'wI' : random.normal(next(skeys), (n,u)) * ifactor,
          'wR' : random.normal(next(skeys), (n,n)) * hfactor,
          'wO' : random.normal(next(skeys), (m,n)) * pfactor,
          'wF' : random.normal(next(skeys), (n,m)) * ffactor,
          'dt_over_tau' : dt / tau}

def new_force_params(n, alpha=1.0):
  """Generate new 'parameters' for the RLS learning rule.

  This routine essentially initializes the inverse correlation matrix in RLS.

  Arguments:
    n: number of neurons
    alpha: initial learning rate

  Returns: 
    A dictionary with RLS parameters.
  """
  identity_3d = np.zeros((n,n,n))
  idx = np.arange(n)
  identity_3d[:, idx, idx] = 1    

  return {'P' : jnp.eye(n) * alpha, 'P_recurr': jnp.array(identity_3d) * alpha}

def esn(x, a, h, z, wI, wR, wF, wO, dtdivtau):
  """Run the continuous-time Echostate network one step.
  
    da/dt = -a + wI x + wR h + wF z (last part not needed for no feedback ESN)

    Arguments:
      x: ndarray of input to ESN
      a: ndarray of pre-activations from prev time step
      h: ndarray of neuron firing rates from prev time step
      z: ndarray of output from prev time step
      wI: ndarray, input matrix, shape (n, u)
      wR: ndarray, recurrent matrix, shape (n, n)
      wF: ndarray, feedback matrix, shape (n, m)
      wO: ndarray, output matrix, shape (m, n)
      dtdivtau: dt / tau

    Returns: 
      The update to the ESN at this time step.
  """
  dadt = -a + jnp.dot(wI, x) + jnp.dot(wR, h) # + np.dot(wF, z) # feedback removed
  a = a + dtdivtau * dadt
  h = jnp.tanh(a)
  z = jnp.dot(wO, h)
  
  return a, h, z

def rls(h, z, f, wO, P):
  """Perform the recursive least squares step for the output kernel.
  
    Arguments: 
      h: ndarray of neuron firing rates from prev time step
      z: ndarray of output at current time step
      f: ndarray of targets at current time step
      wO: ndarray of output weights, shape (m, n)
      P: ndarray, inverse correlation matrix, shape (n,n)

    Returns: 
      A 4-tuple of the updated wO, updated P, and delta w and P
  """
  k = jnp.expand_dims(jnp.dot(P, h), axis=1)
  hPh = jnp.dot(h.T, k)
  c = 1.0 / (1.0 + hPh)

  dP = jnp.dot(c * k, jnp.dot(jnp.expand_dims(h, axis=0), P))
  P = P - dP

  e = jnp.atleast_2d(z - f)
  dw = jnp.dot(jnp.expand_dims(jnp.dot(P, h), axis=1), e).T

  return wO - dw, P, dw, dP     

def update_recurr_P(h, z, f, P_recurr, wR):
  """Perform the recursive least squares step for the recurrent kernel.
  
    Arguments: 
      h: ndarray of neuron firing rates from prev time step
      z: ndarray of output at current time step
      f: ndarray of targets at current time step
      P_recurr: ndarray, inverse correlation matrix, shape (n,n,n)
      wR: ndarray of recurrent weights, shape (n,n)

    Returns: 
      A 4-tuple of the updated wR, updated P_recurr, and delta wR and P_recurr
  """
  h = jnp.expand_dims(h, axis=1)
  Ph = jnp.dot(P_recurr, h)[:,:,0] # need to multiply by error term to get n x n matrix of weight updates (indiced by i x j)
  hPh = jnp.expand_dims(jnp.dot(Ph, h), axis=2) # n x 1 x 1 array for i
  htP = jnp.dot(jnp.transpose(h),P_recurr)[0] # indiced by i x k, n x n matrix 
  
  dP_recurr = jnp.expand_dims(Ph, axis=2) * jnp.expand_dims(htP, axis=1)  / (1 + hPh) 
  P_recurr -= dP_recurr
  e = jnp.atleast_2d(z - f)
  assert e.shape == (1,1)
  dwR = e * jnp.dot(P_recurr, h)[:,:,0]

  return wR - dwR, P_recurr, dwR, dP_recurr

# %%
def esn_run_and_train_jax(params, fparams, x_t, f_t=None, do_train=False):
  """Run the Echostate network forward a number of steps the length of x_t.
  
    This implementation uses JAX to build the outer time loop from basic
    Python for loop.

    Arguments: 
      params: dict of ESN params
      fparams: dict of RLS params
      x_t: ndarray of input time series, shape (t, u)
      f_t: ndarray of target time series, shape (t, m)
      do_train: Should the network be trained on this run? 
    
    Returns:
      4-tuple of params, fparams, h_t, z_t, after running ESN and potentially
        updating the readout vector.  
  """
  # per-example predictions
  a = params['a0']
  h = jnp.tanh(a)
  wO = params['wO']
  wI = params['wI']
  wR = params['wR']
  wF = params['wF']
  z = jnp.dot(wO, h)
  if do_train:
    P = fparams['P']
    P_recurr = fparams['P_recurr']
  else:
    P = None
    P_recurr = None
  h_t = []
  z_t = []

  dP = 0
  dw = 0
  dtdivtau = params['dt_over_tau']

  for tidx, x in enumerate(x_t):
    a, h, z = esn(x, a, h, z, wI, wR, wF, wO, dtdivtau)

    if do_train:
      wO, P, dw, dP = rls(h, z, f_t[tidx], wO, P)
      wR, P_recurr, dwR, dP_recurr = update_recurr_P(h, z, f_t[tidx], P_recurr, wR)
    h_t.append(h)
    z_t.append(z)
    
  if do_train:
    fparams['P'] = P
    fparams['P_recurr'] = P_recurr
  params['wO'] = wO
  params['wR'] = wR
  params['a0'] = a
  
  h_t = jnp.array(h_t)  
  z_t = jnp.array(z_t)
  return params, fparams, h_t, z_t

def esn_run_jax(params, x_t):
  """Run the echostate network forward.

    Arguments:
      params: dict of ESN params
      x_t: ndarray of input with shape (t,u)

    Returns: 
      2-tuple of ndarrays of neuron firing rates and the outputs.
  """
  _, _, h_t, z_t  = esn_run_and_train_jax(params, None, x_t, 
                                          None, do_train=False)
  return h_t, z_t

esn_run_jax_jit = jit(esn_run_jax)

def esn_train_jax(params, fparams, x_t, f_t):
  """Run the echostate network forward and also train it.

    Arguments:
      params: dict of ESN params
      fparams: dict of RLS params
      x_t: ndarray of inputs with shape (t,u)
      f_t: ndarray of targets with shape (t,m)

    Returns: 
      4-tuple of updated params, fparams, and also ndarrays 
        of neuron firing rates and the outputs.
  """
  return esn_run_and_train_jax(params, fparams, x_t, f_t, do_train=True)
  
esn_train_jax_jit = jit(esn_train_jax)

# %% [markdown]
# # Define Sum of Sinusoid Target

# %%
def fullforce_oscillation_test(dt, showplots=0):
    dt_per_s = round(1/dt)
    
    # From the paper, and the online demo:
    t = np.expand_dims(np.linspace(0,2,2*dt_per_s+1),1)
    omega = np.zeros((2*dt_per_s+1,1))
    omega = np.linspace(2*np.pi, 6*np.pi, 1*dt_per_s+1)
    targ = np.zeros((2*dt_per_s+1,1))
    targ[0:(1*dt_per_s+1),0] = np.sin(t[0:(1*dt_per_s+1),0]*omega)
    targ[1*dt_per_s:(2*dt_per_s+1)] = -np.flipud(targ[0:(1*dt_per_s+1)])
    
    # A simpler example: just a sine wave
    '''
    t = np.expand_dims(np.linspace(0,2,2*dt_per_s+1),1)
    omega = np.ones((2*dt_per_s+1,1)) * 4 *np.pi
    targ = np.sin(t*omega)
    '''
    
    # A slightly harder example: sum of sine waves
    
    t = np.expand_dims(np.linspace(0,2,2*dt_per_s+1),1)
    omega = np.ones((2*dt_per_s+1,1)) * 4 *np.pi
    targ = np.sin(t*2*omega) * np.sin(t*omega/4)
    
    
    inp = np.zeros(targ.shape)
    inp[0:round(0.05*dt_per_s),0] = np.ones((round(0.05*dt_per_s)))
    hints = np.zeros(targ.shape)

    if showplots == 1:
        plt.figure()
        plt.plot(targ)
        plt.plot(hints)
        plt.plot(inp)
        plt.legend(['Target','Hints','Input'])
    
    return inp, targ, hints

# %% [markdown]
# # Create input and target

# %%
tau = 0.025 * 2
dt =  tau / 10

inp, targ, hints = fullforce_oscillation_test(dt=dt, showplots=1)
targ = targ.astype(np.float32)
inp = inp.astype(np.float32)
assert inp.shape[0] == targ.shape[0]
print(targ.shape)

u = inp.shape[1] # input dimension
alpha = 1e0 # constant for initializing the P matrix
m = targ.shape[1] # output dimension
g = 1.5 # gain parameter that controls the chaos
# Out:
# (401, 1)

# %% [markdown]
# # Find running time by using numpy implementation

# %%
# %%time 

functional_final_dict = {}
for n in neuron_list:
  time_n_overall = []
  for trial_idx in range(ntrial):
    print('Trial: ', trial_idx)
    params_seed = np.random.randint(0, 10000000)
    print("Params seed %d" %(params_seed))
    key = random.PRNGKey(params_seed)
    init_params = random_esn_params(key, u, n, m, tau=tau, dt=dt, g=g)

    # Copy the params to the ones we will be training.
    params = dict.copy(init_params)
    fparams = new_force_params(n, alpha=alpha)

    mae_history = []
    time_jax = []
    for train_idx in range(n_epoch):
      start = time.time()
      # replace esn_train_jax with esn_train_jax_jit for jit optimization
      params, fparams, h_t, z_t = esn_train_jax(params, fparams, jnp.array(inp), jnp.array(targ)) 
      time_jax.append(time.time() - start)
      mae_history.append(jnp.mean(jnp.abs(z_t - targ)).item())
      print(f'Epoch: {train_idx + 1} Time: {round(time_jax[-1],4)}','MAE: ', round(mae_history[-1], 4))
    time_n_overall.append(time_jax)
  functional_final_dict[n] = np.array(time_n_overall)
  assert functional_final_dict[n].shape == (ntrial, n_epoch)
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# Trial:  0
# Params seed 8470861
# Epoch: 1 Time: 14.557 MAE:  0.2379
# Epoch: 2 Time: 1.2691 MAE:  0.3321
# Epoch: 3 Time: 1.2612 MAE:  0.3398
# Epoch: 4 Time: 1.2675 MAE:  0.3784
# Epoch: 5 Time: 1.2768 MAE:  0.3289
# Trial:  1
# Params seed 8020753
# Epoch: 1 Time: 1.2842 MAE:  0.2809
# Epoch: 2 Time: 1.2824 MAE:  0.3282
# Epoch: 3 Time: 1.5216 MAE:  0.2834
# Epoch: 4 Time: 1.2976 MAE:  0.309
# Epoch: 5 Time: 1.3015 MAE:  0.2979
# Trial:  2
# Params seed 6765817
# Epoch: 1 Time: 1.255 MAE:  0.2277
# Epoch: 2 Time: 1.2537 MAE:  0.3204
# Epoch: 3 Time: 1.2725 MAE:  0.334
# Epoch: 4 Time: 1.2609 MAE:  0.34
# Epoch: 5 Time: 1.269 MAE:  0.3299
# Trial:  3
# Params seed 2686457
# Epoch: 1 Time: 1.2724 MAE:  0.2297
# Epoch: 2 Time: 1.27 MAE:  0.3547
# Epoch: 3 Time: 1.2764 MAE:  0.3907
# Epoch: 4 Time: 1.2581 MAE:  0.3555
# Epoch: 5 Time: 1.2718 MAE:  0.3661
# Trial:  4
# Params seed 5071945
# Epoch: 1 Time: 1.2777 MAE:  0.2802
# Epoch: 2 Time: 1.2801 MAE:  0.3626
# Epoch: 3 Time: 1.2527 MAE:  0.3829
# Epoch: 4 Time: 1.2657 MAE:  0.3832
# Epoch: 5 Time: 1.2896 MAE:  0.388
# Trial:  0
# Params seed 9140777
# Epoch: 1 Time: 1.9412 MAE:  0.1913
# Epoch: 2 Time: 1.3406 MAE:  0.2651
# Epoch: 3 Time: 1.3393 MAE:  0.294
# Epoch: 4 Time: 1.3674 MAE:  0.3787
# Epoch: 5 Time: 1.3582 MAE:  0.3482
# Trial:  1
# Params seed 7295685
# Epoch: 1 Time: 1.3986 MAE:  0.1257
# Epoch: 2 Time: 2.0521 MAE:  0.163
# Epoch: 3 Time: 1.7414 MAE:  0.2645
# Epoch: 4 Time: 1.3405 MAE:  0.2554
# Epoch: 5 Time: 1.3307 MAE:  0.1845
# Trial:  2
# Params seed 9753125
# Epoch: 1 Time: 1.3424 MAE:  0.1241
# Epoch: 2 Time: 1.3236 MAE:  0.3016
# Epoch: 3 Time: 1.3425 MAE:  0.3174
# Epoch: 4 Time: 1.3573 MAE:  0.3465
# Epoch: 5 Time: 1.3428 MAE:  0.2916
# Trial:  3
# Params seed 4023633
# Epoch: 1 Time: 1.3646 MAE:  0.2017
# Epoch: 2 Time: 1.3206 MAE:  0.2544
# Epoch: 3 Time: 1.3381 MAE:  0.2514
# Epoch: 4 Time: 1.352 MAE:  0.2544
# Epoch: 5 Time: 1.3339 MAE:  0.2514
# Trial:  4
# Params seed 1508761
# Epoch: 1 Time: 1.35 MAE:  0.1774
# Epoch: 2 Time: 1.3628 MAE:  0.2932
# Epoch: 3 Time: 1.3441 MAE:  0.2767
# Epoch: 4 Time: 1.337 MAE:  0.2723
# Epoch: 5 Time: 1.3469 MAE:  0.3313
# Trial:  0
# Params seed 2010137
# Epoch: 1 Time: 2.4382 MAE:  0.0813
# Epoch: 2 Time: 1.7796 MAE:  0.124
# Epoch: 3 Time: 1.7747 MAE:  0.2282
# Epoch: 4 Time: 1.7536 MAE:  0.1733
# Epoch: 5 Time: 1.742 MAE:  0.1745
# Trial:  1
# Params seed 5674363
# Epoch: 1 Time: 1.7394 MAE:  0.152
# Epoch: 2 Time: 1.7758 MAE:  0.2082
# Epoch: 3 Time: 1.7631 MAE:  0.2052
# Epoch: 4 Time: 1.8185 MAE:  0.1526
# Epoch: 5 Time: 1.7575 MAE:  0.147
# Trial:  2
# Params seed 2563261
# Epoch: 1 Time: 1.7377 MAE:  0.0865
# Epoch: 2 Time: 1.7495 MAE:  0.1444
# Epoch: 3 Time: 1.7453 MAE:  0.1643
# Epoch: 4 Time: 1.7479 MAE:  0.12
# Epoch: 5 Time: 1.7611 MAE:  0.1158
# Trial:  3
# Params seed 469869
# Epoch: 1 Time: 1.7613 MAE:  0.059
# Epoch: 2 Time: 1.7228 MAE:  0.1355
# Epoch: 3 Time: 1.741 MAE:  0.1429
# Epoch: 4 Time: 1.7796 MAE:  0.2203
# Epoch: 5 Time: 1.806 MAE:  0.1271
# Trial:  4
# Params seed 4615056
# Epoch: 1 Time: 1.7451 MAE:  0.1026
# Epoch: 2 Time: 1.7607 MAE:  0.107
# Epoch: 3 Time: 1.7623 MAE:  0.1292
# Epoch: 4 Time: 1.7844 MAE:  0.0727
# Epoch: 5 Time: 1.7741 MAE:  0.1125
# Trial:  0
# Params seed 6734883
# Epoch: 1 Time: 3.0487 MAE:  0.0554
# Epoch: 2 Time: 2.4286 MAE:  0.0821
# Epoch: 3 Time: 2.3614 MAE:  0.0741
# Epoch: 4 Time: 2.4263 MAE:  0.0759
# Epoch: 5 Time: 2.3914 MAE:  0.0924
# Trial:  1
# Params seed 5179077
# Epoch: 1 Time: 2.3975 MAE:  0.0603
# Epoch: 2 Time: 2.4006 MAE:  0.0685
# Epoch: 3 Time: 2.4129 MAE:  0.1573
# Epoch: 4 Time: 2.4103 MAE:  0.1198
# Epoch: 5 Time: 2.4686 MAE:  0.1551
# Trial:  2
# Params seed 7791085
# Epoch: 1 Time: 2.4636 MAE:  0.0847
# Epoch: 2 Time: 2.4617 MAE:  0.1477
# Epoch: 3 Time: 2.4165 MAE:  0.1376
# Epoch: 4 Time: 2.4213 MAE:  0.1352
# Epoch: 5 Time: 2.4215 MAE:  0.1708
# Trial:  3
# Params seed 922797
# Epoch: 1 Time: 2.4598 MAE:  0.0953
# Epoch: 2 Time: 2.4763 MAE:  0.1268
# Epoch: 3 Time: 2.4535 MAE:  0.1228
# Epoch: 4 Time: 2.7777 MAE:  0.1699
# Epoch: 5 Time: 2.5039 MAE:  0.1651
# Trial:  4
# Params seed 7132274
# Epoch: 1 Time: 2.4372 MAE:  0.2068
# Epoch: 2 Time: 2.4521 MAE:  0.3269
# Epoch: 3 Time: 2.4064 MAE:  0.3319
# Epoch: 4 Time: 2.4056 MAE:  0.3295
# Epoch: 5 Time: 2.486 MAE:  0.2701
# Trial:  0
# Params seed 6341306
# Epoch: 1 Time: 4.4354 MAE:  0.05
# Epoch: 2 Time: 3.7103 MAE:  0.0952
# Epoch: 3 Time: 3.6492 MAE:  0.0904
# Epoch: 4 Time: 3.7308 MAE:  0.1297
# Epoch: 5 Time: 3.71 MAE:  0.1185
# Trial:  1
# Params seed 9752979
# Epoch: 1 Time: 3.8125 MAE:  0.0516
# Epoch: 2 Time: 3.7774 MAE:  0.0985
# Epoch: 3 Time: 3.764 MAE:  0.1353
# Epoch: 4 Time: 3.7469 MAE:  0.179
# Epoch: 5 Time: 3.817 MAE:  0.1852
# Trial:  2
# Params seed 3437091
# Epoch: 1 Time: 3.7369 MAE:  0.099
# Epoch: 2 Time: 3.7521 MAE:  0.1634
# Epoch: 3 Time: 3.7874 MAE:  0.1321
# Epoch: 4 Time: 3.7401 MAE:  0.1464
# Epoch: 5 Time: 3.727 MAE:  0.1553
# Trial:  3
# Params seed 7304297
# Epoch: 1 Time: 3.7038 MAE:  0.0465
# Epoch: 2 Time: 3.659 MAE:  0.061
# Epoch: 3 Time: 3.7105 MAE:  0.1217
# Epoch: 4 Time: 3.6562 MAE:  0.177
# Epoch: 5 Time: 3.6619 MAE:  0.2172
# Trial:  4
# Params seed 8817651
# Epoch: 1 Time: 3.7392 MAE:  0.1219
# Epoch: 2 Time: 3.7185 MAE:  0.1498
# Epoch: 3 Time: 3.7286 MAE:  0.131
# Epoch: 4 Time: 3.7354 MAE:  0.1873
# Epoch: 5 Time: 3.6969 MAE:  0.2646
# CPU times: user 4min 49s, sys: 7.06 s, total: 4min 56s
# Wall time: 4min 46s

# %% [markdown]
# # Find running time by training using tension

# %%
targ_tensor = tf.convert_to_tensor(targ, dtype=tf.float32) 
inp_tensor = tf.convert_to_tensor(inp, dtype=tf.float32)

# %%
tension_final_dict = {}
for n in neuron_list:
  time_tension = []
  for trial_idx in range(ntrial):
    print('Trial ', trial_idx)
    time_history = TimeHistory()
    myesn = NoFeedbackESN(dtdivtau=dt/tau, units=n, output_size=m, activation='tanh')
    model = FORCEModel(force_layer=myesn, alpha_P=alpha) 
    model.compile(metrics=["mae"])
    history = model.fit(x=inp_tensor,
                        y=targ_tensor, 
                        epochs=n_epoch, 
                        callbacks=[time_history])
    time_tension.append(time_history.times)
  tension_final_dict[n] = np.array(time_tension)
  assert tension_final_dict[n].shape == (ntrial, n_epoch)
# Out:
# Trial  0
# Epoch 1/5
# 401/401 [==============================] - 2s 1ms/step - mae: 0.3798
# Epoch 2/5
# 401/401 [==============================] - 0s 1ms/step - mae: 0.4070
# Epoch 3/5
# 401/401 [==============================] - 0s 1ms/step - mae: 0.3998
# Epoch 4/5
# 401/401 [==============================] - 0s 1ms/step - mae: 0.3925
# Epoch 5/5
# 401/401 [==============================] - 0s 1ms/step - mae: 0.3818
# Trial  1
# Epoch 1/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.2145
# Epoch 2/5
# 401/401 [==============================] - 0s 1ms/step - mae: 0.3171
# Epoch 3/5
# 401/401 [==============================] - 0s 1ms/step - mae: 0.2343
# Epoch 4/5
# 401/401 [==============================] - 0s 1ms/step - mae: 0.2630
# Epoch 5/5
# 401/401 [==============================] - 0s 1ms/step - mae: 0.3072
# Trial  2
# Epoch 1/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.1723
# Epoch 2/5
# 401/401 [==============================] - 0s 1ms/step - mae: 0.2991
# Epoch 3/5
# 401/401 [==============================] - 0s 1ms/step - mae: 0.4056
# Epoch 4/5
# 401/401 [==============================] - 0s 1ms/step - mae: 0.3534
# Epoch 5/5
# 401/401 [==============================] - 0s 1ms/step - mae: 0.3286
# Trial  3
# Epoch 1/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.1863
# Epoch 2/5
# 401/401 [==============================] - 0s 1ms/step - mae: 0.2216
# Epoch 3/5
# 401/401 [==============================] - 0s 1ms/step - mae: 0.1506
# Epoch 4/5
# 401/401 [==============================] - 0s 1ms/step - mae: 0.1963
# Epoch 5/5
# 401/401 [==============================] - 0s 1ms/step - mae: 0.1342
# Trial  4
# Epoch 1/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.2674
# Epoch 2/5
# 401/401 [==============================] - 0s 1ms/step - mae: 0.3385
# Epoch 3/5
# 401/401 [==============================] - 0s 1ms/step - mae: 0.4176
# Epoch 4/5
# 401/401 [==============================] - 0s 1ms/step - mae: 0.3959
# Epoch 5/5
# 401/401 [==============================] - 0s 1ms/step - mae: 0.4367
# Trial  0
# Epoch 1/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.2601
# Epoch 2/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.2813
# Epoch 3/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.3429
# Epoch 4/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.3873
# Epoch 5/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.3622
# Trial  1
# Epoch 1/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.1363
# Epoch 2/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.1646
# Epoch 3/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.2862
# Epoch 4/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.2318
# Epoch 5/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.2804
# Trial  2
# Epoch 1/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.1441
# Epoch 2/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.1779
# Epoch 3/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.2199
# Epoch 4/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.2827
# Epoch 5/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.3101
# Trial  3
# Epoch 1/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.2320
# Epoch 2/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.2953
# Epoch 3/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.2661
# Epoch 4/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.2928
# Epoch 5/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.2461
# Trial  4
# Epoch 1/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.2050
# Epoch 2/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.2877
# Epoch 3/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.3453
# Epoch 4/5
# 401/401 [==============================] - 1s 1ms/step - mae: 0.3105
# Epoch 5/5
# 401/401 [==============================] - 0s 1ms/step - mae: 0.3082
# Trial  0
# Epoch 1/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.1480
# Epoch 2/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.2699
# Epoch 3/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.3675
# Epoch 4/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.3096
# Epoch 5/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.3006
# Trial  1
# Epoch 1/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.0903
# Epoch 2/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.1277
# Epoch 3/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.2283
# Epoch 4/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.2709
# Epoch 5/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.2968
# Trial  2
# Epoch 1/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.2003
# Epoch 2/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.2782
# Epoch 3/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.3715
# Epoch 4/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.3279
# Epoch 5/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.3765
# Trial  3
# Epoch 1/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.1688
# Epoch 2/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.1374
# Epoch 3/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.2670
# Epoch 4/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.2512
# Epoch 5/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.2761
# Trial  4
# Epoch 1/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.1671
# Epoch 2/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.1900
# Epoch 3/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.2120
# Epoch 4/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.2111
# Epoch 5/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.3122
# Trial  0
# Epoch 1/5
# 401/401 [==============================] - 2s 3ms/step - mae: 0.0770
# Epoch 2/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.1072
# Epoch 3/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.1421
# Epoch 4/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.1305
# Epoch 5/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.2681
# Trial  1
# Epoch 1/5
# 401/401 [==============================] - 2s 3ms/step - mae: 0.0572
# Epoch 2/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.0930
# Epoch 3/5
# 401/401 [==============================] - 1s 3ms/step - mae: 0.0863
# Epoch 4/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.1541
# Epoch 5/5
# 401/401 [==============================] - 1s 3ms/step - mae: 0.1523
# Trial  2
# Epoch 1/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.0772
# Epoch 2/5
# 401/401 [==============================] - 1s 3ms/step - mae: 0.0823
# Epoch 3/5
# 401/401 [==============================] - 1s 3ms/step - mae: 0.1177
# Epoch 4/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.1276
# Epoch 5/5
# 401/401 [==============================] - 1s 3ms/step - mae: 0.0732
# Trial  3
# Epoch 1/5
# 401/401 [==============================] - 2s 2ms/step - mae: 0.0808
# Epoch 2/5
# 401/401 [==============================] - 1s 3ms/step - mae: 0.1124
# Epoch 3/5
# 401/401 [==============================] - 1s 3ms/step - mae: 0.1201
# Epoch 4/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.2075
# Epoch 5/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.1548
# Trial  4
# Epoch 1/5
# 401/401 [==============================] - 2s 2ms/step - mae: 0.0466
# Epoch 2/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.0760
# Epoch 3/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.1134
# Epoch 4/5
# 401/401 [==============================] - 1s 3ms/step - mae: 0.1562
# Epoch 5/5
# 401/401 [==============================] - 1s 2ms/step - mae: 0.2035
# Trial  0
# Epoch 1/5
# 401/401 [==============================] - 2s 4ms/step - mae: 0.1207
# Epoch 2/5
# 401/401 [==============================] - 2s 4ms/step - mae: 0.1586
# Epoch 3/5
# 401/401 [==============================] - 2s 4ms/step - mae: 0.1872
# Epoch 4/5
# 401/401 [==============================] - 2s 4ms/step - mae: 0.1648
# Epoch 5/5
# 401/401 [==============================] - 2s 4ms/step - mae: 0.1341
# Trial  1
# Epoch 1/5
# 401/401 [==============================] - 2s 4ms/step - mae: 0.1115
# Epoch 2/5
# 401/401 [==============================] - 2s 4ms/step - mae: 0.1343
# Epoch 3/5
# 401/401 [==============================] - 2s 4ms/step - mae: 0.1488
# Epoch 4/5
# 401/401 [==============================] - 2s 4ms/step - mae: 0.1476
# Epoch 5/5
# 401/401 [==============================] - 2s 4ms/step - mae: 0.1366
# Trial  2
# Epoch 1/5
# 401/401 [==============================] - 2s 4ms/step - mae: 0.0921
# Epoch 2/5
# 401/401 [==============================] - 2s 4ms/step - mae: 0.0810
# Epoch 3/5
# 401/401 [==============================] - 2s 4ms/step - mae: 0.0932
# Epoch 4/5
# 401/401 [==============================] - 2s 4ms/step - mae: 0.0996
# Epoch 5/5
# 401/401 [==============================] - 2s 4ms/step - mae: 0.1435
# Trial  3
# Epoch 1/5
# 401/401 [==============================] - 2s 4ms/step - mae: 0.0599
# Epoch 2/5
# 401/401 [==============================] - 2s 4ms/step - mae: 0.0916
# Epoch 3/5
# 401/401 [==============================] - 2s 4ms/step - mae: 0.0948
# Epoch 4/5
# 401/401 [==============================] - 2s 4ms/step - mae: 0.1000
# Epoch 5/5
# 401/401 [==============================] - 2s 4ms/step - mae: 0.1563
# Trial  4
# Epoch 1/5
# 401/401 [==============================] - 2s 4ms/step - mae: 0.0834
# Epoch 2/5
# 401/401 [==============================] - 2s 4ms/step - mae: 0.1023
# Epoch 3/5
# 401/401 [==============================] - 2s 4ms/step - mae: 0.1073
# Epoch 4/5
# 401/401 [==============================] - 2s 4ms/step - mae: 0.1454
# Epoch 5/5
# 401/401 [==============================] - 2s 4ms/step - mae: 0.1090

# %% [markdown]
# # Time Comparison Plots Plots

# %%
functional_result = []
for key, val in functional_final_dict.items():
  temp = np.mean(val, axis=1)
  functional_result.append([key, np.mean(temp), np.std(temp, ddof=1)])

functional_result = np.array(functional_result)

# %%
tension_result = []
for key, val in tension_final_dict.items():
  temp = np.mean(val, axis=1)
  tension_result.append([key, np.mean(temp), np.std(temp, ddof=1)])

tension_result = np.array(tension_result)

# %%
fig, (ax1) = plt.subplots(1, 1, sharey = True, figsize=(5,4))

ax1.errorbar(tension_result[:,0], tension_result[:,1], yerr=tension_result[:,2], label='Our API', color='r', linewidth=1.5, capsize=3)
ax1.errorbar(functional_result[:,0], functional_result[:,1], yerr=functional_result[:,2], label='Standard Numpy', color='b', linewidth=1.5, capsize=3)

ax1.set_xticks(functional_result[:,0])
ax1.set_xlabel('Number of Recurrent Neurons')
ax1.set_ylabel('Time (s)')
ax1.legend(loc='upper left')
ax1.set_title('\n')

sns.despine(ax=ax1)
